# %% [markdown]
# <a href="https://colab.research.google.com/github/zohaib166/python_general/blob/main/Pandas_Practice1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns

sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
data = sns.load_dataset('mpg')

# %%
data.shape
# Out:
# (398, 9)

# %%
data.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'origin', 'name'],
#       dtype='object')

# %%
data.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
data.loc[:,'origin'].unique()
# Out:
# array(['usa', 'japan', 'europe'], dtype=object)

# %%
data.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  392.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.491160   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  126.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year
# count    398.000000  398.000000
# mean      15.568090   76.010050
# std        2.757689    3.697627
# min        8.000000   70.000000
# 25%       13.825000   73.000000
# 50%       15.500000   76.000000
# 75%       17.175000   79.000000
# max       24.800000   82.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %%
import copy
data1 = copy.deepcopy(data)

# %%
data1['modelYear'] = 1900+data1['model_year']

# %%
data1.drop('model_year', axis = 1, inplace=True)

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   origin        398 non-null    object
#  7   name          398 non-null    object
#  8   modelYear     398 non-null    int64
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %%
data1.rename(columns = {'modelYear':'model_year'}, inplace=True)

# %%
data1.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration origin  \
# 0  18.0          8         307.0       130.0    3504          12.0    usa
# 1  15.0          8         350.0       165.0    3693          11.5    usa
# 2  18.0          8         318.0       150.0    3436          11.0    usa
# 3  16.0          8         304.0       150.0    3433          12.0    usa
# 4  17.0          8         302.0       140.0    3449          10.5    usa
#
#                         name  model_year
# 0  chevrolet chevelle malibu        1970
# 1          buick skylark 320        1970
# 2         plymouth satellite        1970
# 3              amc rebel sst        1970
# 4                ford torino        1970

# %%
data1.columns = data1.columns.str.title()

# %%
data1.columns
# Out:
# Index(['Mpg', 'Cylinders', 'Displacement', 'Horsepower', 'Weight',
#        'Acceleration', 'Origin', 'Name', 'Model_Year'],
#       dtype='object')

# %%
data1.columns.str.replace('_','')
# Out:
# Index(['Mpg', 'Cylinders', 'Displacement', 'Horsepower', 'Weight',
#        'Acceleration', 'Origin', 'Name', 'ModelYear'],
#       dtype='object')

# %%
data1['Horsepower'].mean()
# Out:
# 104.46938775510205

# %%
data1.shape
# Out:
# (398, 9)

# %%
data1.sort_values(['Mpg'])
# Out:
#       Mpg  Cylinders  Displacement  Horsepower  Weight  Acceleration  Origin  \
# 28    9.0          8         304.0       193.0    4732          18.5     usa
# 25   10.0          8         360.0       215.0    4615          14.0     usa
# 26   10.0          8         307.0       200.0    4376          15.0     usa
# 103  11.0          8         400.0       150.0    4997          14.0     usa
# 124  11.0          8         350.0       180.0    3664          11.0     usa
# ..    ...        ...           ...         ...     ...           ...     ...
# 326  43.4          4          90.0        48.0    2335          23.7  europe
# 394  44.0          4          97.0        52.0    2130          24.6  europe
# 325  44.3          4          90.0        48.0    2085          21.7  europe
# 329  44.6          4          91.0        67.0    1850          13.8   japan
# 322  46.6          4          86.0        65.0    2110          17.9   japan
#
#                      Name  Model_Year
# ...

# %%
data1.head()
# Out:
#     Mpg  Cylinders  Displacement  Horsepower  Weight  Acceleration Origin  \
# 0  18.0          8         307.0       130.0    3504          12.0    usa
# 1  15.0          8         350.0       165.0    3693          11.5    usa
# 2  18.0          8         318.0       150.0    3436          11.0    usa
# 3  16.0          8         304.0       150.0    3433          12.0    usa
# 4  17.0          8         302.0       140.0    3449          10.5    usa
#
#                         Name  Model_Year
# 0  chevrolet chevelle malibu        1970
# 1          buick skylark 320        1970
# 2         plymouth satellite        1970
# 3              amc rebel sst        1970
# 4                ford torino        1970

# %%
data1[(data1['Cylinders'] > 4) & (data1['Weight'] > 3500)]
# Out:
#       Mpg  Cylinders  Displacement  Horsepower  Weight  Acceleration  Origin  \
# 0    18.0          8         307.0       130.0    3504          12.0     usa
# 1    15.0          8         350.0       165.0    3693          11.5     usa
# 5    15.0          8         429.0       198.0    4341          10.0     usa
# 6    14.0          8         454.0       220.0    4354           9.0     usa
# 7    14.0          8         440.0       215.0    4312           8.5     usa
# ..    ...        ...           ...         ...     ...           ...     ...
# 291  19.2          8         267.0       125.0    3605          15.0     usa
# 292  18.5          8         360.0       150.0    3940          13.0     usa
# 297  25.4          5         183.0        77.0    3530          20.1  europe
# 298  23.0          8         350.0       125.0    3900          17.4     usa
# 364  26.6          8         350.0       105.0    3725          19.0     usa
#
# ...

# %%
data1['Name'].unique().size
# Out:
# 305

# %%
data1.groupby(['Origin'])[['Mpg','Cylinders','Displacement','Horsepower','Weight','Acceleration']].mean()
# Out:
#               Mpg  Cylinders  Displacement  Horsepower       Weight  \
# Origin
# europe  27.891429   4.157143    109.142857   80.558824  2423.300000
# japan   30.450633   4.101266    102.708861   79.835443  2221.227848
# usa     20.083534   6.248996    245.901606  119.048980  3361.931727
#
#         Acceleration
# Origin
# europe     16.787143
# japan      16.172152
# usa        15.033735
